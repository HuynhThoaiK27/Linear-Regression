# %% [markdown]
# <a href="https://www.kaggle.com/code/thoihunhvn/crosskd?scriptVersionId=213815951" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Cài đặt

# %%
# !pip install torch==1.12.1 torchvision==0.13.1 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113

# !pip install -U openmim

# !mim install "mmengine==0.7.3"

# !mim install "mmcv==2.0.0rc4"
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 486.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 60.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 87.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.0
#     Uninstalling torchaudio-2.4.0:
#       Successfully uninstalled torchaudio-2.4.0
# ...

# %%
# !git clone https://github.com/jbwang1997/CrossKD
# %cd CrossKD
# Out:
# Cloning into 'CrossKD'...
# remote: Enumerating objects: 34364, done.
# remote: Counting objects: 100% (1845/1845), done.
# remote: Compressing objects: 100% (371/371), done.
# remote: Total 34364 (delta 1650), reused 1526 (delta 1473), pack-reused 32519 (from 1)
# Receiving objects: 100% (34364/34364), 32.17 MiB | 32.85 MiB/s, done.
# Resolving deltas: 100% (26896/26896), done.
# /kaggle/working/CrossKD

# %%
# !pip install -v -e .
# "-v" means verbose, or more output
# "-e" means installing a project in editable mode,
# thus any local modifications made to the code will take effect without reinstallation.

# !pip install yapf==0.32.0
# Out:
# Using pip 24.0 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///kaggle/working/CrossKD
#   Running command python setup.py egg_info
#   /opt/conda/lib/python3.10/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
#   ERROR: setuptools==60.2.0 is used in combination with setuptools_scm>=8.x
#
#   Your build configuration is incomplete and previously worked by accident!
#   setuptools_scm requires setuptools>=61
#
#   Suggested workaround if applicable:
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-5j84ldsj/mmdet.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-5j84ldsj/mmdet.egg-info/SOURCES.txt'
# ...

# %% [markdown]
# # Thực hiện các bước di chuyển và cài đặt cấu hình

# %%
# di chuyển các thư mục dẫn VOC và thêm lớp cấu hình CrossKDFasterRCNN vào mmdet/models/detectors/__init__.py
# !cp /kaggle/input/faster-rcnn-teacher/voc0712_faster_rcnn.py configs/_base_/datasets/voc0712.py
# !cp /kaggle/input/setting/__init.py mmdet/models/detectors/__init__.py

# %%
# tạo thư mục faster_rcnn trong configs
# !mkdir configs/faster_rcnn

# %%
# !ls configs
# Out:
# _base_	centernet  crosskd+pkd	fcos  ld
# atss	crosskd    faster_rcnn	gfl   retinanet

# %%
# di chuyển cấu hình model_teacher (FasterRCNN_101) đến thư mục 'configs/faster_rcnn'
# !cp /kaggle/input/fasterrcnn-101-teacher/faster-rcnn_r101_fpn_1x_voc0712.py configs/faster_rcnn/

# %%
# cấu hình huấn luyện CrossKD cho mô hình FasterRCNN
# !cp /kaggle/input/crosskd-fasterrcnn-test/crosskd_fasterRCNN_101_50.py configs/crosskd/

# %%
# cấu hình cho Lớp CrossKDFasterRCNN
# !cp /kaggle/input/lop-crosskd-fasterrcnn-00/crosskd_faster_rcnn.py mmdet/models/detectors/

# %%
# Huấn luyện
# !python tools/train.py configs/crosskd/crosskd_fasterRCNN_101_50.py --work-dir /kaggle/working/
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 12/19 07:57:24 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     numpy_random_seed: 955799129
#     GPU 0,1: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 1.12.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# ...

# %% [markdown]
# # Huấn luyện lại model_TEACHER_R101

# %%
# %cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# !mkdir model_teacher_101

# %%
# !ls /kaggle/working/
# Out:
# 20241219_075723  CrossKD  __notebook__.ipynb  model_teacher_101

# %%
# %cd /kaggle/working/CrossKD
# Out:
# /kaggle/working/CrossKD

# %%
# !cp /kaggle/input/fasterrcnn-101-teacher/faster-rcnn_r101_fpn_1x_voc0712.py configs/faster_rcnn/faster-rcnn_r101_fpn_1x_voc0712.py

# %%
# !python tools/train.py configs/faster_rcnn/faster-rcnn_r101_fpn_1x_voc0712.py --work-dir /kaggle/working/model_teacher_101
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 12/19 07:57:40 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     numpy_random_seed: 1939057858
#     GPU 0,1: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 1.12.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# ...
